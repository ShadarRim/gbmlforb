# %%
import numpy as np
import pandas as pd 
import random

import statsmodels.api as sm

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.feature_selection import SelectKBest, SelectPercentile, SelectFromModel
from sklearn.feature_selection import f_regression, mutual_info_regression

from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Path_Brent = 'my_BRENT2019.csv'

# %%
data = pd.read_csv(Path_Brent, index_col=[0], parse_dates=[0])

data.head()
# Out:
#             Значение  year  month  dayofmonth  quarter  dayofyear  weekofyear  \
# Дата
# 2010-09-01     76.37  2010      9           1        3        244          35
# 2010-09-02     76.89  2010      9           2        3        245          35
# 2010-09-03     76.57  2010      9           3        3        246          35
# 2010-09-04     76.62  2010      9           4        3        247          35
# 2010-09-05     76.63  2010      9           5        3        248          35
#
#             dayofweek  is_holiday  is_prev_holiday  is_next_holiday
# Дата
# 2010-09-01          2           0                0                0
# 2010-09-02          3           0                0                0
# 2010-09-03          4           0                0                0
# 2010-09-04          5           0                0                0
# 2010-09-05          6           0                1                0

# %%
first_diff =np.array(data.iloc[1:,0].values - data.iloc[:-1,0].values).astype('float32') 
data['diff1'] = 0.0
data['diff1'] =  data['diff1'].astype('float') 
data['diff1'].values[1:] = first_diff

# %%
data.head()
# Out:
#             Значение  year  month  dayofmonth  quarter  dayofyear  weekofyear  \
# Дата
# 2010-09-01     76.37  2010      9           1        3        244          35
# 2010-09-02     76.89  2010      9           2        3        245          35
# 2010-09-03     76.57  2010      9           3        3        246          35
# 2010-09-04     76.62  2010      9           4        3        247          35
# 2010-09-05     76.63  2010      9           5        3        248          35
#
#             dayofweek  is_holiday  is_prev_holiday  is_next_holiday  diff1
# Дата
# 2010-09-01          2           0                0                0   0.00
# 2010-09-02          3           0                0                0   0.52
# 2010-09-03          4           0                0                0  -0.32
# 2010-09-04          5           0                0                0   0.05
# 2010-09-05          6           0                1                0   0.01

# %%
data_w = data.copy().resample('W').mean()
data_w.shape
# Out:
# (470, 12)

# %%
data_w
# Out:
#              Значение    year     month  dayofmonth   quarter   dayofyear  \
# Дата
# 2010-09-05  76.616000  2010.0  9.000000    3.000000  3.000000  246.000000
# 2010-09-12  77.673333  2010.0  9.000000    8.500000  3.000000  251.500000
# 2010-09-19  78.693333  2010.0  9.000000   15.666667  3.000000  258.666667
# 2010-09-26  78.518333  2010.0  9.000000   22.666667  3.000000  265.666667
# 2010-10-03  81.211667  2010.0  9.333333   19.666667  3.333333  272.666667
# ...               ...     ...       ...         ...       ...         ...
# 2019-08-04  62.791667  2019.0  7.500000   16.166667  3.000000  212.666667
# 2019-08-11  58.236667  2019.0  8.000000    7.666667  3.000000  219.666667
# 2019-08-18  59.033333  2019.0  8.000000   14.666667  3.000000  226.666667
# 2019-08-25  59.495000  2019.0  8.000000   21.666667  3.000000  233.666667
# 2019-09-01  59.348333  2019.0  8.166667   23.500000  3.000000  240.666667
#
#             weekofyear  dayofweek  is_holiday  is_prev_holiday  \
# Дата
# 2010-09-05        35.0   4.000000    0.000000         0.200000
# 2010-09-12        36.0   2.500000    0.166667         0.000000
# 2010-09-19        37.0   2.666667    0.000000         0.000000
# 2010-09-26        38.0   2.666667    0.000000         0.000000
# 2010-10-03        39.0   2.666667    0.000000         0.000000
# ...                ...        ...         ...              ...
# 2019-08-04        31.0   2.666667    0.000000         0.000000
# 2019-08-11        32.0   2.666667    0.000000         0.000000
# 2019-08-18        33.0   2.666667    0.000000         0.000000
# 2019-08-25        34.0   2.666667    0.000000         0.000000
# 2019-09-01        35.0   2.666667    0.000000         0.166667
#
#             is_next_holiday     diff1
# Дата
# 2010-09-05         0.000000  0.052000
# 2010-09-12         0.166667  0.288333
# 2010-09-19         0.000000 -0.021667
# 2010-09-26         0.000000  0.118333
# 2010-10-03         0.000000  0.791667
# ...                     ...       ...
# 2019-08-04         0.000000 -0.286667
# 2019-08-11         0.000000 -0.510000
# 2019-08-18         0.000000  0.103333
# 2019-08-25         0.000000 -0.180000
# 2019-09-01         0.000000  0.171667
#
# [470 rows x 12 columns]

# %%
file_name = 'RC_F01_09_2010_T01_09_2019.xlsx'
data_usd = pd.read_excel(file_name, index_col=[0], parse_dates=[0]).sort_index()
print(data_usd.shape)
data_usd.head(2)
# Out:
# (2228, 3)
#               data     curs         cdx
# nominal
# 1       2010-09-01  30.8669  Доллар США
# 1       2010-09-02  30.8001  Доллар США

# %%
data_usd = data_usd.set_index('data').drop('cdx', axis=1)
data_usd.columns = ['usd']
data_usd = data_usd.resample('W').mean()
data_usd.head()
# Out:
#                  usd
# data
# 2010-09-05  30.76125
# 2010-09-12  30.79402
# 2010-09-19  30.84672
# 2010-09-26  30.99920
# 2010-10-03  30.52764

# %%
data_usd.loc[1:, 'usd_diff_1'] = data_usd['usd'][:-1].values - data_usd['usd'][1:].values
data_usd.head(2)
# Out:
#                  usd  usd_diff_1
# data
# 2010-09-05  30.76125         NaN
# 2010-09-12  30.79402    -0.03277

# %%
file_name = 'R_E01_09_2010_T01_09_2019.xlsx'
data_e = pd.read_excel(file_name, index_col=[0], parse_dates=[0]).sort_index()
print(data_e.shape)
data_e.head(2)
# Out:
# (2228, 3)
#               data     curs   cdx
# nominal
# 1       2010-09-01  39.0127  Евро
# 1       2010-09-02  39.1654  Евро

# %%
data_e = data_e.set_index('data').drop('cdx', axis=1)
data_e.columns = ['eur']
data_e = data_e.resample('W').mean()
data_e.head()
# Out:
#                   eur
# data
# 2010-09-05  39.204675
# 2010-09-12  39.293360
# 2010-09-19  39.977740
# 2010-09-26  41.042640
# 2010-10-03  41.351660

# %%
data_e.loc[1:, 'eur_diff_1'] = data_e['eur'][:-1].values - data_e['eur'][1:].values
data_usd.head(2)
# Out:
#                  usd  usd_diff_1
# data
# 2010-09-05  30.76125         NaN
# 2010-09-12  30.79402    -0.03277

# %%
data_w = pd.concat([data_w, data_usd.usd_diff_1, data_e.eur_diff_1], axis=1)
TARGET_NAME = 'Значение'
data_w.head(2)
# Out:
#              Значение    year  month  dayofmonth  quarter  dayofyear  \
# Дата
# 2010-09-05  76.616000  2010.0    9.0         3.0      3.0      246.0
# 2010-09-12  77.673333  2010.0    9.0         8.5      3.0      251.5
#
#             weekofyear  dayofweek  is_holiday  is_prev_holiday  \
# Дата
# 2010-09-05        35.0        4.0    0.000000              0.2
# 2010-09-12        36.0        2.5    0.166667              0.0
#
#             is_next_holiday     diff1  usd_diff_1  eur_diff_1
# Дата
# 2010-09-05         0.000000  0.052000         NaN         NaN
# 2010-09-12         0.166667  0.288333    -0.03277   -0.088685

# %%
data_w.columns
# Out:
# Index(['Значение', 'year', 'month', 'dayofmonth', 'quarter', 'dayofyear',
#        'weekofyear', 'dayofweek', 'is_holiday', 'is_prev_holiday',
#        'is_next_holiday', 'diff1', 'usd_diff_1', 'eur_diff_1'],
#       dtype='object')

# %%
features = ['Значение', 'year', 'month', 'weekofyear', 'diff1', 'usd_diff_1', 'eur_diff_1']

# %%
data_w_f = data_w[features]
data_w_f.head()
# Out:
#              Значение    year     month  weekofyear     diff1  usd_diff_1  \
# Дата
# 2010-09-05  76.616000  2010.0  9.000000        35.0  0.052000         NaN
# 2010-09-12  77.673333  2010.0  9.000000        36.0  0.288333    -0.03277
# 2010-09-19  78.693333  2010.0  9.000000        37.0 -0.021667    -0.05270
# 2010-09-26  78.518333  2010.0  9.000000        38.0  0.118333    -0.15248
# 2010-10-03  81.211667  2010.0  9.333333        39.0  0.791667     0.47156
#
#             eur_diff_1
# Дата
# 2010-09-05         NaN
# 2010-09-12   -0.088685
# 2010-09-19   -0.684380
# 2010-09-26   -1.064900
# 2010-10-03   -0.309020

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))
lag = 15

sm.graphics.tsa.plot_acf(data_w_f['Значение'].values[100:], lags=lag, ax=axes[0])
sm.graphics.tsa.plot_pacf(data_w_f['Значение'].values[100:], lags=lag, ax=axes[1])
plt.show()

# %%
def train_test_split(data, split_date, h=1):
    ind = data.index
    
    X = data.loc[ind[:-h], ['year', 'month', 'weekofyear', 'diff1', 'usd_diff_1', 'eur_diff_1']]    
    y = data.loc[ind[h:], 'Значение']    
    
    df = X
    df.loc[:, TARGET_NAME] = y.values
    
    df_train = df[df.index.get_level_values('Дата') < split_date]
    df_test = df[df.index.get_level_values('Дата') >= split_date]    
    
    return df_train, df_test

# %%
split_date = '2018-02-02'
df_train, df_test = train_test_split(data_w_f, split_date)

# %%
plt.figure( figsize=(20, 4))
plt.xlabel('Время')
plt.ylabel('Значение')
plt.plot(df_train.index[100:], df_train['Значение'][100:], label='train' )
plt.plot(df_test.index, df_test['Значение'], label='test')
plt.title(f'Нефть - train & test', size=14)
plt.legend()
plt.show()

# %%
model_gb = GradientBoostingRegressor(max_depth=3, random_state=42, n_estimators=100)
model_gb.fit(df_train['year', 'month', 'weekofyear', 'diff1', 'usd_diff_1', 'eur_diff_1'], df_train['Значение'])

y_pred = model_gb.predict(df_test['year', 'month', 'weekofyear', 'diff1', 'usd_diff_1', 'eur_diff_1'])

y = df_test['Значение']
mse = mean_squared_error(y, y_pred) 
mae = mean_absolute_error(y, y_pred) 
R2 = r2_score(y, y_pred)
mape = mean_absolute_percentage_error(y, y_pred)
print(f'mse:\t{round(mse, 3)}\nmae:\t{round(mae, 3)}\nR2:\t{round(R2, 3)}\nmape:\t{round(mape, 3)}%')

plot_predictions(y, y_pred)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('year', 'month', 'weekofyear', 'diff1', 'usd_diff_1', 'eur_diff_1')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-9fb09db7441d> in <module>
#       1 model_gb = GradientBoostingRegressor(max_depth=3, random_state=42, n_estimators=100)
# ----> 2 model_gb.fit(df_train['year', 'month', 'weekofyear', 'diff1', 'usd_diff_1', 'eur_diff_1'], df_train['Значение'])
#       3
#       4 y_pred = model_gb.predict(df_test['year', 'month', 'weekofyear', 'diff1', 'usd_diff_1', 'eur_diff_1'])
#       5
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('year', 'month', 'weekofyear', 'diff1', 'usd_diff_1', 'eur_diff_1')
